# %%
# Loading in SQL extension
# %reload_ext sql
# Initiating a DuckDB database named 'bank_data.duck.db' to run SQL queries
# %sql duckdb:///car_data.duckdb

# %% [markdown]
# # Queries to explore
# 1. Bar plot with three groups (fuel, hybrid, electric). X axis is year and y axis is count. This way we can examine car manufacturing trends
# 2. Scatter plot of electric vehicle ranges and charging time
# 3. Bar plot with three groups (fuel, hybrid, electric). X axis is `vehicleclass_` and y axis is count.
# 4. Bubble plot of fuel vehicles, x axis is `co2emissions_g(g/km)`, y axis is `fuelconsumption_comb(mpg)`, and bubble size is `enginesize_(l)`
# 5.

# %%
# %sql select * from fuel
# Out:
# Running query in 'duckdb:///car_data.duckdb'
# +------------+-------+-------------------+----------------+----------------+------------+---------------+-----------+-------------------------------+------------------------------+-------------------------------+---------------------------+---------------------+------------+-------------+-----------------------------+-----------------+------------------+---------------------+----+--------------+
# | model_year | make_ |      model.1_     | vehicleclass_  | enginesize_(l) | cylinders_ | transmission_ | fuel_type | fuelconsumption_city(l/100km) | fuelconsumption_hwy(l/100km) | fuelconsumption_comb(l/100km) | fuelconsumption_comb(mpg) | co2emissions_(g/km) | co2_rating | smog_rating |      transmission_type      | number_of_gears | mapped_fuel_type | type_of_wheel_drive | id | vehicle_type |
# ...

# %%
# %sql select * from electric
# Out:
# Running query in 'duckdb:///car_data.duckdb'
# +------------+------------+---------------------------------+---------------+------------+---------------+-----------+-----------------------------+--------------------------------+---------------------------------+--------------------------------+-------------------------------+--------------------------------+------------+---------------------+------------+-------------+------------------+-------------------+-----------------+------------------+----+--------------+
# | model_year |   make_    |             model.1_            | vehicleclass_ | motor_(kw) | transmission_ | fuel_type | consumption_city(kwh/100km) | fuelconsumption_hwy(kwh/100km) | fuelconsumption_comb(kwh/100km) | fuelconsumption_city(le/100km) | fuelconsumption_hwy(le/100km) | fuelconsumption_comb(le/100km) | range_(km) | co2emissions_(g/km) | co2_rating | smog_rating | recharge_time(h) | transmission_type | number_of_gears | mapped_fuel_type | id | vehicle_type |
# ...

# %%
# %sql select * from hybrid
# Out:
# Running query in 'duckdb:///car_data.duckdb'
# +------------+-----------+----------------------+---------------+------------+----------------+------------+---------------+------------+---------------------------------+-------------+------------------+------------+-------------------------------+------------------------------+-------------------------------+-------------+---------------------+------------+-------------+-----------------------+-----------------+------------------+--------------------------------+----+--------------+
# ...
